# %% [markdown]
# # CS 4661
# # Kevin Tong
# ## Homework 4
# ## 304708110

# %%
# Importing our libraries and such
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.utils import resample
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# %%
# Assigning dataframe and creating decision tree for later

cancer_df = pd.read_csv('D:\System\Documents\GitKraken\CS4661\src\homework-4\Cancer.csv')
# cancer_df = pd.read_csv('https://raw.githubusercontent.com/mpourhoma/CS4661/master/cancer.csv')
dt = DecisionTreeClassifier(random_state=3)

# %%
cancer_df[0::10]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Clump_Thickness</th>
#       <th>Uniformity_of_Cell_Size</th>
#       <th>Uniformity_of_Cell_Shape</th>
#       <th>Marginal_Adhesion</th>
#       <th>Single_Epithelial_Cell_Size</th>
#       <th>Bare_Nuclei</th>
#       <th>Bland_Chromatin</th>
#       <th>Normal_Nucleoli</th>
#       <th>Mitoses</th>
#       <th>Malignant_Cancer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>5</td>
#       <td>3</td>
#       <td>3</td>
#       <td>3</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>4</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>5</td>
#       <td>4</td>
#       <td>4</td>
#       <td>9</td>
#       <td>2</td>
#       <td>10</td>
#       <td>5</td>
#       <td>6</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>9</td>
#       <td>5</td>
#       <td>8</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>2</td>
#       <td>1</td>
#       <td>5</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>5</td>
#       <td>3</td>
#       <td>5</td>
#       <td>5</td>
#       <td>3</td>
#       <td>3</td>
#       <td>4</td>
#       <td>10</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>5</td>
#       <td>1</td>
#       <td>3</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>7</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>10</td>
#       <td>3</td>
#       <td>5</td>
#       <td>1</td>
#       <td>10</td>
#       <td>5</td>
#       <td>3</td>
#       <td>10</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>1</td>
#       <td>3</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>5</td>
#       <td>3</td>
#       <td>2</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>5</td>
#       <td>3</td>
#       <td>5</td>
#       <td>1</td>
#       <td>8</td>
#       <td>10</td>
#       <td>5</td>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>110</th>
#       <td>5</td>
#       <td>5</td>
#       <td>5</td>
#       <td>6</td>
#       <td>3</td>
#       <td>10</td>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>120</th>
#       <td>8</td>
#       <td>6</td>
#       <td>5</td>
#       <td>4</td>
#       <td>3</td>
#       <td>10</td>
#       <td>6</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>130</th>
#       <td>8</td>
#       <td>7</td>
#       <td>6</td>
#       <td>4</td>
#       <td>4</td>
#       <td>10</td>
#       <td>5</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>140</th>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Assigning x and y with features and label
# Create a python list of feature names that would like to pick from the dataset:
features = [
    'Clump_Thickness',
    'Uniformity_of_Cell_Size', 
    'Uniformity_of_Cell_Shape',
    'Marginal_Adhesion', 
    'Single_Epithelial_Cell_Size', 
    'Bare_Nuclei',
    'Bland_Chromatin',
    'Normal_Nucleoli',
    'Mitoses'
]

x = cancer_df[features]
y = cancer_df['Malignant_Cancer']

print('x head\n')
print(x.head())
print('\ny head\n')
print(y.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4cee19d38c32> in <module>
#      13 ]
#      14
# ---> 15 x = cancer_df[features]
#      16 y = cancer_df['Malignant_Cancer']
#      17
#
# NameError: name 'cancer_df' is not defined

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-730fdf6b9661> in <module>
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=3)
#       2
#
# NameError: name 'x' is not defined

# %%
# print the size of the traning set:
print(x_train.shape)
print(y_train.shape)

# print the size of the testing set:
print(x_test.shape)
print(y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cce45e56b51f> in <module>
#       1 # print the size of the traning set:
# ----> 2 print(x_train.shape)
#       3 print(y_train.shape)
#       4
#       5 # print the size of the testing set:
#
# NameError: name 'x_train' is not defined

# %%
# Training on training set
dt.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-124d3a1e4183> in <module>
#       1 # Training on training set
# ----> 2 dt.fit(x_train, y_train)
#
# NameError: name 'dt' is not defined

# %%
# Testing on testing set
y_predict_dt = dt.predict(x_test)
print(y_predict_dt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d9cb1ca571e4> in <module>
#       1 # Testing on testing set
# ----> 2 y_predict_dt = dt.predict(x_test)
#       3 print(y_predict_dt)
#
# NameError: name 'dt' is not defined

# %%
# Testing our accuracy
dt_accuracy = accuracy_score(y_test, y_predict_dt)
print(dt_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-580bc686a6a5> in <module>
#       1 # Testing our accuracy
# ----> 2 dt_accuracy = accuracy_score(y_test, y_predict_dt)
#       3 print(dt_accuracy)
#
# NameError: name 'y_test' is not defined

# %%
# Doing bagging

prediction_scores = []

for i in range(0, 19):
    bootstrap_size = int(0.8 * len(x_train))
    x_bag, y_bag = resample(x_train, y_train, n_samples=bootstrap_size, random_state=i, replace=True)
    base_dt = DecisionTreeClassifier(random_state=3)
    base_dt.fit(x_bag, y_bag)
    y_predict = base_dt.predict(x_test)
    accuracy = accuracy_score(y_test, y_predict)
    prediction_scores.append(accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3169d152af16> in <module>
#       4
#       5 for i in range(0, 19):
# ----> 6     bootstrap_size = int(0.8 * len(x_train))
#       7     x_bag, y_bag = resample(x_train, y_train, n_samples=bootstrap_size, random_state=i, replace=True)
#       8     base_dt = DecisionTreeClassifier(random_state=3)
#
# NameError: name 'x_train' is not defined

# %%
for i in range(len(prediction_scores)):
    print(prediction_scores[i])

# %%
# Final accuracy of our vote

best_score = max(prediction_scores)
print(best_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-dfca23a0ac25> in <module>
#       1 # Final accuracy of our vote
#       2
# ----> 3 best_score = max(prediction_scores)
#       4 print(best_score)
#
# ValueError: max() arg is an empty sequence

# %%
# Creating Random Forest

my_forest = RandomForestClassifier(n_estimators=19, bootstrap=True, random_state=3)

# %%
# Training forest on training set
my_forest.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d9efe8e41d97> in <module>
#       1 # Training forest on training set
# ----> 2 my_forest.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
# Testing forest on testing set
tree_predict = my_forest.predict(x_test)
print(tree_predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-508ce87afce3> in <module>
#       1 # Testing forest on testing set
# ----> 2 tree_predict = my_forest.predict(x_test)
#       3 print(tree_predict)
#
# NameError: name 'x_test' is not defined

# %%
tree_accuracy = accuracy_score(y_test, tree_predict)
print(tree_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-aa88283c2078> in <module>
# ----> 1 tree_accuracy = accuracy_score(y_test, tree_predict)
#       2 print(tree_accuracy)
#
# NameError: name 'y_test' is not defined
